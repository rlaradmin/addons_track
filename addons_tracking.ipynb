# %% [markdown]
# ### Tracking of Add-on from PNOC File

# %%
# Libraries
import pandas as pd

# %%
# Import of current addons spreadsheet from pnoc file.

path = r""  # leave it for testing. 
#path = input("Enter the path to the current pnoc file: ").strip('"')  # leave it for final version.
pnoc_addons = pd.read_excel(path,
                             sheet_name="Add-ons",
                               skiprows=1, usecols="B:O")
df = pnoc_addons.copy()

# %%
# Remove unnecessary columns and rows

df = df.drop(columns=['Unnamed: 5'])
df = df.dropna(subset=['Update'])

# %%
# Rename columns for easier access
df = df.rename(columns={
    'Biscuits': 'Biscuits US',
    'Confy': 'Confy US',
    'Biscuits.1': 'Biscuits CA',
    'Confy.1': 'Confy CA'})
